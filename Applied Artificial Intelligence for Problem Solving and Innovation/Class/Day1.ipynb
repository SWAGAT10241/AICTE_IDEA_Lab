# %%
import pandas as pd

data = {
    'Hours_Studied': [1, 2, 3, 4, 5, 6, 7, 8],
    'Marks': [30,35,45,50,60,65,75,85]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Hours_Studied  Marks
# 0              1     30
# 1              2     35
# 2              3     45
# 3              4     50
# 4              5     60
# 5              6     65
# 6              7     75
# 7              8     85

# %%
# Replacing missing data
df.fillna(df.mean(),inplace = True)

print("\nAfter Preprocessing:")
print(df)
# Out:
# After Preprocessing:
#    Hours_Studied  Marks
# 0              1     30
# 1              2     35
# 2              3     45
# 3              4     50
# 4              5     60
# 5              6     65
# 6              7     75
# 7              8     85

# %%
# Visulaizing the data

import matplotlib.pyplot as plt

hours = [1,2,3,4,5,6]
marks = [30,40,45,55,65,80]

plt.plot(hours,marks,marker='o',markerfacecolor='red',color = 'blue')
plt.title("Study Hours Vs Marks")
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.grid(True)
plt.show()

# %%
from matplotlib import color_sequences
import matplotlib.pyplot as plt

subjects = ['Math','Science','English','Computer']
marks = [80,75,85,90]


colour = ['pink','green','orange','cyan']
plt.bar(subjects,marks,color = colour)

plt.title('Subject-Wise Marks')
plt.xlabel('Subjects')
plt.ylabel('Marks')
plt.grid(True)
plt.show()
